# %% [markdown]
# # 🌍 Population Analysis Report
#
# ## 📌 Introduction
# This notebook analyzes **global population distribution** across different regions using **Python** and **data visualization** tools.
#
# ## 📊 Dataset Overview
# - **Dataset Name:** Population Data (`train.csv` / `POPULATION.csv`)
# - **Columns:** Country, Population, Year, Growth Rate, etc.
# - **Source:** [Data Source](https://www.canva.com/link?target=https%3A%2F%2Fdata.worldbank.org%2Findicator%2FSP.POP.TOTL&design=DAFpRxy47kU&utl=h61d045f407&accessRole=viewer&linkSource=document)
#
# ## 🔍 Objectives
# - Understand **population distribution** by continent.
# - Analyze **growth trends** over time.
# - Visualize data using **Matplotlib & Seaborn**.
#
# ## 📌 Libraries Used
# ```python
#
# 🟢  numpy
# 🟢  pandas
# 🟢  matplotlib.pyplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# %matplotlib inline

# %%
import pandas as pd
population_Data = pd.read_csv('POPULATION.csv', encoding='latin1')

# %%
population_Data.head(5)
# Out:
#      Year Economy Code  Male Population  Female Population  Total Population
# 0     NaN          NaN              NaN                NaN               NaN
# 1  2023.0          AFG       20924078.0         20530683.0        41454761.0
# 2  2023.0          ALB        1357630.0          1388342.0         2745972.0
# 3  2023.0          DZA       23549235.0         22614984.0        46164219.0
# 4  2023.0          ASM          24001.0            23520.0           47521.0

# %%
import pandas as pd


population_Data = pd.read_csv('POPULATION.csv')


print(population_Data.columns)
# Out:
# Index(['Year', 'Economy Code', 'Male Population', 'Female Population',
#        'Total Population'],
#       dtype='object')

# %%
#Total Population distribtion by Different regions of world

import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('POPULATION.csv')





region_size = 5
df['Region'] = df.index // region_size


region_population = df.groupby('Region')['Total Population'].sum()


plt.figure(figsize=(40, 20))
plt.bar(region_population.index, region_population, color="skyblue", edgecolor="black")


plt.xlabel("Region (Groups of 5 countries)")
plt.ylabel("Total Population (Billions)")
plt.title("Population by Region in 2023")
plt.xticks(rotation=45)


plt.show()

# %%
#Population by Gender differentiation....

import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('POPULATION.csv')





region_size = 5
df['Region'] = df.index // region_size


region_population = df.groupby('Region')[['Total Population', 'Male Population', 'Female Population']].sum()


region_population.plot(kind='bar', figsize=(10, 6), color=["skyblue", "lightcoral", "lightgreen"], edgecolor="black")


plt.xlabel("Region (Groups of 5 countries)")
plt.ylabel("Population (Billions)")
plt.title("Population by Region in 2023: Total, Male, and Female")
plt.xticks(rotation=45)


plt.show()
